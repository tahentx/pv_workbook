# %%
import pandas as pd

# %%
df = pd.read_csv("https://plants.usda.gov/java/stateDownload?statefips=US06")
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['symbol', 'synonym symbol', 'scientific name with author',
#        'national common name', 'family'],
#       dtype='object')

# %%
# Out:
# {'Acanthaceae',
#  'Acarosporaceae',
#  'Aceraceae',
#  'Acoraceae',
#  'Agavaceae',
#  'Aizoaceae',
#  'Alismataceae',
#  'Aloaceae',
#  'Amaranthaceae',
#  'Anacardiaceae',
#  'Apiaceae',
#  'Apocynaceae',
#  'Aponogetonaceae',
#  'Aquifoliaceae',
#  'Araceae',
#  'Araliaceae',
#  'Arecaceae',
#  'Aristolochiaceae',
#  'Asclepiadaceae',
#  'Aspleniaceae',
#  'Asteraceae',
#  'Azollaceae',
#  'Bacidiaceae',
#  'Balsaminaceae',
#  'Basellaceae',
#  'Bataceae',
#  'Berberidaceae',
#  'Betulaceae',
#  'Bignoniaceae',
#  'Blechnaceae',
#  'Boraginaceae',
#  'Brassicaceae',
#  'Bryaceae',
#  'Buddlejaceae',
#  'Burseraceae',
#  'Cabombaceae',
#  'Cactaceae',
#  'Callitrichaceae',
#  'Calycanthaceae',
#  'Campanulaceae',
#  'Cannabaceae',
#  'Capparaceae',
#  'Caprifoliaceae',
#  'Caryophyllaceae',
#  'Caulerpaceae',
#  'Celastraceae',
#  'Ceratophyllaceae',
#  'Chenopodiaceae',
#  'Cistaceae',
#  'Cladoniaceae',
#  'Clusiaceae',
#  'Commelinaceae',
#  'Convolvulaceae',
#  'Cornaceae',
# ...
