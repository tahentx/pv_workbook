# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('sm3.csv')
df.head()
# Out:
#    Unnamed: 0       Event ID   Ack.         Event Type  \
# 0         NaN  EG-0016219746  UNACK  Inverter Degraded
# 1         NaN  EG-0016219661  UNACK  Inverter Degraded
# 2         NaN  EG-0016200056  UNACK    Plant Comm Loss
# 3         NaN  EG-0016217778  UNACK  Inverter Degraded
# 4         NaN  EG-0016217624  UNACK  Inverter Degraded
#
#                     Event Code  \
# 0  PF200 - Production Degraded
# 1  PF200 - Production Degraded
# 2  PF400 - Communication Issue
# 3  PF200 - Production Degraded
# 4  PF200 - Production Degraded
#
#                                                Plant                Asset  \
# 0                  047 - San Diego Inspiration Point      INV04 - INV - 4
# 1        006 - City of San Diego- Point Loma Library        INV01 - INV-1
# 2                                009 - Kings Highway  009 - Kings Highway
# 3  042 - Stockton East Water District -  Low Side...  INV10 - INVERTER 10
# ...

# %%
sd_sites = df[df['Plant'].str.contains('San Diego')]

# %%
sd_sites.astype({'Energy Loss  (kWh)': 'float64'}).dtypes
# Out:
# Unnamed: 0              float64
# Event ID                 object
# Ack.                     object
# Event Type               object
# Event Code               object
# Plant                    object
# Asset                    object
# Start Time               object
# End Time                 object
# Duration                 object
# Energy Loss  (kWh)      float64
# Rate Loss  (kWh / h)    float64
# Work Order               object
# Work Order Status        object
# Controllable             object
# Responsibility           object
# Level 1                 float64
# Level 2                 float64
# Level 3                  object
# Level 4                  object
# Level 5                  object
# Level 4.1                object
# Level 5.1                object
# NERC Performance        float64
# FEH Level 1             float64
# FEH Level 2             float64
# System                  float64
# Component               float64
# E_Loss                  float64
# ...

# %%
sd_sites['E_Loss'].sum()
# Out:
# 5886.29136

# %%
sd_sites.sort_values('E_Loss', ascending=False)
# Out:
#       Unnamed: 0       Event ID   Ack.         Event Type  \
# 2704         NaN  EG-0016026990  ACKED  Inverter Degraded
# 2707         NaN  EG-0016026991  ACKED  Inverter Degraded
# 2706         NaN  EG-0016027010  ACKED  Inverter Degraded
# 2705         NaN  EG-0016026989  ACKED  Inverter Degraded
# 1180         NaN  EG-0016140334  UNACK  Inverter Degraded
# 559          NaN  EG-0016184234  UNACK  Inverter Degraded
# 2927         NaN  EG-0016009478  ACKED  Inverter Degraded
# 2329         NaN  EG-0016049688  ACKED  Inverter Degraded
# 315          NaN  EG-0016201995  UNACK  Inverter Degraded
# 221          NaN  EG-0016202545  UNACK  Inverter Degraded
# 851          NaN  EG-0016161320  UNACK  Inverter Degraded
# 1531         NaN  EG-0016121133  UNACK  Inverter Degraded
# 3830         NaN  EG-0015951714  ACKED  Inverter Degraded
# 627          NaN  EG-0016182729  UNACK  Inverter Degraded
# 4971         NaN  EG-0015872184  UNACK  Inverter Degraded
# ...

# %%
sns.boxplot(y=sd_sites['E_Loss'])

# %%
sd_sites['E_Loss'].fillna(0)
# Out:
# 0        0.00000
# 1       10.25193
# 37       0.00000
# 53       0.00000
# 63       0.00000
# 68       3.20827
# 69       7.79315
# 70      10.13138
# 73       0.00000
# 84       0.00000
# 91       1.45681
# 92       0.00000
# 97       7.31675
# 108     17.31066
# 110      0.00000
# 112     19.45634
# 115      7.81514
# 116      0.00000
# 117      3.66517
# 137      4.93750
# 152      0.00000
# 154      0.00000
# 155      1.92904
# 156      2.23563
# 157      2.18146
# 163      0.00000
# 165      1.51792
# 200      4.24139
# 202      7.75130
# 219     21.80991
#           ...
# 9308     1.45461
# 9309     1.11294
# 9319     3.04624
# 9320     2.86928
# 9321     0.00000
# 9322     3.52384
# 9334     0.93361
# 9377     2.57035
# 9379    17.84035
# 9380    20.46535
# 9381    30.15478
# 9384     0.00000
# 9385     5.82787
# 9386     6.86496
# 9388     2.53164
# 9389     4.43914
# 9390     5.12253
# 9391     8.24467
# 9393     0.00000
# 9442    11.08068
# 9443     0.00000
# ...

# %%
sd_sites['E_Loss'].hist(bins=25)
