# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_fwf("weather.dat")

# %%
df2 = df.iloc[:,0:3]
df2.rename(columns={"Dy" : "Day","MxT" : "Max","MnT" : "Min"})  \
   .drop(df2.index[0])  \
   .drop(df.tail(1).index,inplace=True)  \
#    .fillna(method='ffill')  \   
#    .set_index('Day')  \

# %%
df2.dtypes
# Out:
# Dy     object
# MxT    object
# MnT    object
# dtype: object

# %%
df2.fillna(method='ffill')
df2.set_index('Dy')
# Out:
#       MxT   MnT
# Dy
# NaN   NaN   NaN
# 1      88    59
# 2      79    63
# 3      77    55
# 4      77    59
# 5      90    66
# 6      81    61
# 7      73    57
# 8      75    54
# 9      86   32*
# 10     84    64
# 11     91    59
# 12     88    73
# 13     70    59
# 14     61    59
# 15     64    55
# 16     79    59
# 17     81    57
# 18     82    52
# 19     81    61
# 20     84    57
# 21     86    59
# 22     90    64
# 23     90    68
# 24     90    77
# 25     90    72
# 26    97*    64
# 27     91    72
# 28     84    68
# 29     88    66
# 30     90    45
# mo   82.9  60.5

# %%
df2.loc[9,'MnT'] = 32
df2.loc[26,'MxT'] = 97
df2.set_index('Dy')
# Out:
#       MxT   MnT
# Dy
# NaN   NaN   NaN
# 1      88    59
# 2      79    63
# 3      77    55
# 4      77    59
# 5      90    66
# 6      81    61
# 7      73    57
# 8      75    54
# 9      86    32
# 10     84    64
# 11     91    59
# 12     88    73
# 13     70    59
# 14     61    59
# 15     64    55
# 16     79    59
# 17     81    57
# 18     82    52
# 19     81    61
# 20     84    57
# 21     86    59
# 22     90    64
# 23     90    68
# 24     90    77
# 25     90    72
# 26     97    64
# 27     91    72
# 28     84    68
# 29     88    66
# 30     90    45
# mo   82.9  60.5

# %%
df3 = df2.dropna()
df3
# Out:
#     Dy   MxT   MnT
# 1    1    88    59
# 2    2    79    63
# 3    3    77    55
# 4    4    77    59
# 5    5    90    66
# 6    6    81    61
# 7    7    73    57
# 8    8    75    54
# 9    9    86    32
# 10  10    84    64
# 11  11    91    59
# 12  12    88    73
# 13  13    70    59
# 14  14    61    59
# 15  15    64    55
# 16  16    79    59
# 17  17    81    57
# 18  18    82    52
# 19  19    81    61
# 20  20    84    57
# 21  21    86    59
# 22  22    90    64
# 23  23    90    68
# 24  24    90    77
# 25  25    90    72
# 26  26    97    64
# 27  27    91    72
# 28  28    84    68
# 29  29    88    66
# 30  30    90    45
# 31  mo  82.9  60.5

# %%
df4 = df3.drop(df3.index[-1])

# %%
df5 = df4.apply(pd.to_numeric)

# %%
df6 = df5.set_index(['Dy'])

# %%
df6
# Out:
#     MxT  MnT
# Dy
# 1    88   59
# 2    79   63
# 3    77   55
# 4    77   59
# 5    90   66
# 6    81   61
# 7    73   57
# 8    75   54
# 9    86   32
# 10   84   64
# 11   91   59
# 12   88   73
# 13   70   59
# 14   61   59
# 15   64   55
# 16   79   59
# 17   81   57
# 18   82   52
# 19   81   61
# 20   84   57
# 21   86   59
# 22   90   64
# 23   90   68
# 24   90   77
# 25   90   72
# 26   97   64
# 27   91   72
# 28   84   68
# 29   88   66
# 30   90   45

# %%
a = df6['MxT']
# Out:
# Dy
# 1     88
# 2     79
# 3     77
# 4     77
# 5     90
# 6     81
# 7     73
# 8     75
# 9     86
# 10    84
# 11    91
# 12    88
# 13    70
# 14    61
# 15    64
# 16    79
# 17    81
# 18    82
# 19    81
# 20    84
# 21    86
# 22    90
# 23    90
# 24    90
# 25    90
# 26    97
# 27    91
# 28    84
# 29    88
# 30    90
# Name: MxT, dtype: int64

# %%
b = df6['MnT']
b
# Out:
# Dy
# 1     59
# 2     63
# 3     55
# 4     59
# 5     66
# 6     61
# 7     57
# 8     54
# 9     32
# 10    64
# 11    59
# 12    73
# 13    59
# 14    59
# 15    55
# 16    59
# 17    57
# 18    52
# 19    61
# 20    57
# 21    59
# 22    64
# 23    68
# 24    77
# 25    72
# 26    64
# 27    72
# 28    68
# 29    66
# 30    45
# Name: MnT, dtype: int64

# %%
plt.style.use('seaborn-whitegrid')

# %%
df6.reset_index()
# Out:
#     Dy  MxT  MnT
# 0    1   88   59
# 1    2   79   63
# 2    3   77   55
# 3    4   77   59
# 4    5   90   66
# 5    6   81   61
# 6    7   73   57
# 7    8   75   54
# 8    9   86   32
# 9   10   84   64
# 10  11   91   59
# 11  12   88   73
# 12  13   70   59
# 13  14   61   59
# 14  15   64   55
# 15  16   79   59
# 16  17   81   57
# 17  18   82   52
# 18  19   81   61
# 19  20   84   57
# 20  21   86   59
# 21  22   90   64
# 22  23   90   68
# 23  24   90   77
# 24  25   90   72
# 25  26   97   64
# 26  27   91   72
# 27  28   84   68
# 28  29   88   66
# 29  30   90   45

# %%
df6.plot()

# %%
df6['diff'] = df6['MxT'] - df6['MnT']

# %%
df6
# Out:
#     MxT  MnT  diff
# Dy
# 1    88   59    29
# 2    79   63    16
# 3    77   55    22
# 4    77   59    18
# 5    90   66    24
# 6    81   61    20
# 7    73   57    16
# 8    75   54    21
# 9    86   32    54
# 10   84   64    20
# 11   91   59    32
# 12   88   73    15
# 13   70   59    11
# 14   61   59     2
# 15   64   55     9
# 16   79   59    20
# 17   81   57    24
# 18   82   52    30
# 19   81   61    20
# 20   84   57    27
# 21   86   59    27
# 22   90   64    26
# 23   90   68    22
# 24   90   77    13
# 25   90   72    18
# 26   97   64    33
# 27   91   72    19
# 28   84   68    16
# 29   88   66    22
# 30   90   45    45

# %%
df6['diff'].idxmin()
# Out:
# 14
