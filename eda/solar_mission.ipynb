# %%
import pandas as pd
import numpy as np
import matplotlib as plt

df = pd.read_csv('sm3.csv')
solar_mission = df.set_index(['Plant','Asset','Event Type','Start Time']).sort_index(axis=0)
solar_mission.tail(10)
# Out:
#                                                                                                 Unnamed: 0  \
# Plant                               Asset                Event Type        Start Time
# 068 - Saddle Brook Long Memorial ES INV01 - Inverter - 2 Inverter Degraded 10/22/2019 10:50:00         NaN
#                                                                            10/23/2019 08:45:00         NaN
#                                                                            10/24/2019 08:45:00         NaN
#                                                                            10/26/2019 08:50:00         NaN
#                                                                            11/01/2019 09:00:00         NaN
#                                                                            11/02/2019 09:05:00         NaN
#                                                                            11/03/2019 08:05:00         NaN
# ...

# %%
solar_mission.loc[pd.IndexSlice[:,:, ['Inverter Degraded','Plant Degraded']], ['Energy Loss (kWh)', 'Ack.']]
# Out:
#                                                                                                  Energy Loss (kWh)  \
# Plant                               Asset                 Event Type        Start Time
# 001 - Halls Warehouse               001 - Halls Warehouse Plant Degraded    10/13/2019 16:40:00                NaN
#                                                                             10/18/2019 11:40:00                NaN
#                                                                             10/28/2019 11:20:00                NaN
#                                                                             11/01/2019 16:15:00                NaN
#                                                                             11/03/2019 11:55:00                NaN
#                                     INV01 - PV 1-1        Inverter Degraded 10/23/2019 16:30:00                NaN
# ...

# %%
solar_mission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 9603 entries, (001 - Halls Warehouse, 001 - Halls Warehouse, Plant Degraded, 10/13/2019 16:40:00) to (068 - Saddle Brook Long Memorial ES, PYR01 - Sun, Comm Loss, 10/06/2019 13:55:00)
# Data columns (total 24 columns):
# Unnamed: 0              0 non-null float64
# Event ID                9603 non-null object
# Ack.                    9603 non-null object
# Event Code              9603 non-null object
# End Time                9540 non-null object
# Duration                9603 non-null object
# Energy Loss  (kWh)      7531 non-null float64
# Rate Loss  (kWh / h)    7531 non-null float64
# Work Order              9603 non-null object
# Work Order Status       4 non-null object
# Controllable            9603 non-null object
# Responsibility          9603 non-null object
# Level 1                 0 non-null float64
# Level 2                 0 non-null float64
# Level 3                 9603 non-null object
# ...

# %%
solar_mission['Work Order'].head()
# Out:
# Plant                  Asset                  Event Type      Start Time
# 001 - Halls Warehouse  001 - Halls Warehouse  Plant Degraded  10/13/2019 16:40:00    Create
#                                                               10/18/2019 11:40:00    Create
#                                                               10/28/2019 11:20:00    Create
#                                                               11/01/2019 16:15:00    Create
#                                                               11/03/2019 11:55:00    Create
# Name: Work Order, dtype: object

# %%
df['Plant'].nunique()
# Out:
# 65

# %%
df.sample(n=5)
# Out:
#       Unnamed: 0       Event ID   Ack.         Event Type  \
# 1396         NaN  EG-0016136924  UNACK  Inverter Degraded
# 8836         NaN  EG-0015644909  UNACK          Comm Loss
# 8910         NaN  EG-0015640528  UNACK  Inverter Degraded
# 8588         NaN  EG-0015661359  UNACK          Comm Loss
# 989          NaN  EG-0016159388  UNACK  Inverter Degraded
#
#                        Event Code  \
# 1396  PF200 - Production Degraded
# 8836  PF400 - Communication Issue
# 8910  PF200 - Production Degraded
# 8588  PF400 - Communication Issue
# 989   PF200 - Production Degraded
#
#                                                   Plant  \
# 1396        003 - Templeton USD - Templeton High School
# 8836  041 - Stockton East Water District -  High Sid...
# 8910                         028 - Tracy USD -  West HS
# 8588                             043 - Barrette Farms 2
# 989                               001 - Halls Warehouse
#
# ...

# %%
df.sample(frac=0.01)
# Out:
#       Unnamed: 0       Event ID   Ack.         Event Type  \
# 357          NaN  EG-0016200463  UNACK     Plant Degraded
# 4084         NaN  EG-0015963946  UNACK     Plant Degraded
# 6581         NaN  EG-0015807780  UNACK     Plant Degraded
# 6174         NaN  EG-0015824861  UNACK  Inverter Degraded
# 979          NaN  EG-0016158647  UNACK  Inverter Degraded
# 4329         NaN  EG-0015929933  UNACK     Plant Degraded
# 9362         NaN  EG-0015628113  UNACK  Inverter Degraded
# 3757         NaN  EG-0015959836  UNACK          Comm Loss
# 4798         NaN  EG-0015893399  UNACK  Inverter Degraded
# 5134         NaN  EG-0015869410  UNACK  Inverter Degraded
# 5210         NaN  EG-0015867876  UNACK  Inverter Degraded
# 6220         NaN  EG-0015823637  UNACK          Comm Loss
# 9321         NaN  EG-0015612485  UNACK     Plant Degraded
# 6471         NaN  EG-0015816270  UNACK  Inverter Degraded
# 8529         NaN  EG-0015666298  UNACK          Comm Loss
# ...

# %%
df.iloc[100:105]
# Out:
#      Unnamed: 0       Event ID   Ack.         Event Type  \
# 100         NaN  EG-0016217016  UNACK  Inverter Degraded
# 101         NaN  EG-0016216959  UNACK  Inverter Degraded
# 102         NaN  EG-0016216961  UNACK  Inverter Degraded
# 103         NaN  EG-0016217024  UNACK  Inverter Degraded
# 104         NaN  EG-0016216958  UNACK  Inverter Degraded
#
#                       Event Code                          Plant  \
# 100  PF200 - Production Degraded  017 - Tracy USD -  Kimball HS
# 101  PF200 - Production Degraded  017 - Tracy USD -  Kimball HS
# 102  PF200 - Production Degraded  017 - Tracy USD -  Kimball HS
# 103  PF200 - Production Degraded  017 - Tracy USD -  Kimball HS
# 104  PF200 - Production Degraded  017 - Tracy USD -  Kimball HS
#
#                        Asset           Start Time             End Time  \
# 100  INV12 - Inverter No. 12  11/05/2019 08:00:00  11/05/2019 09:40:00
# 101   INV06 - Inverter No. 6  11/05/2019 08:00:00  11/05/2019 09:40:00
# ...

# %%
df["Energy Loss  (kWh)"].mean()
# Out:
# 17.255033960961363

# %%
df["Energy Loss  (kWh)"].median()
# Out:
# 6.2484

# %%
group = solar_mission.groupby(level=2)

for key, item in group:
    print(group.get_group(key), "\n\n")
# Out:
#                                                                                                          Unnamed: 0  \
# Plant                                            Asset                   Event Type Start Time
# 009 - Kings Highway                              INV01 - INV-1           Comm Loss  06/14/2018 20:05:00         NaN
#                                                  INV02 - INV-2           Comm Loss  06/14/2018 20:05:00         NaN
# 016 - Burlington High School -  Cambridge        INV01 - Inverter 1      Comm Loss  10/12/2019 06:50:00         NaN
#                                                                                     10/23/2019 06:30:00         NaN
#                                                  INV02 - Inverter 2      Comm Loss  10/12/2019 06:50:00         NaN
#                                                                                     10/23/2019 06:30:00         NaN
# ...
