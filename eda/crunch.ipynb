# %%
import pandas as pd
import re
df = pd.read_csv('startups.csv')

# %%
df.head()
# Out:
#                     name     city  \
# 0          Campus Bubble  Atlanta
# 1               DueProps  Atlanta
# 2              SalesLoft  Atlanta
# 3  The Coca-Cola Company  Atlanta
# 4              EarthLink  Atlanta
#
#                                              tagline  \
# 0                             Your Academic Identity
# 1  Gamifying the $46 Billion Employee Incentives ...
# 2          Quickly build high-quality prospect lists
# 3                                                NaN
# 4                                                NaN
#
#                                          description
# 0  Campus Bubble (“CB”) is the Academic Community...
# 1                                t unprecedented ...
# 2                build high-quality prospect lists\n
# 3  Coca-Cola Journey is a digital magazine that f...
# 4                                                NaN

# %%
df.shape
# Out:
# (42038, 4)

# %%
df.dropna()
# Out:
#                                              name           city  \
# 0                                   Campus Bubble        Atlanta
# 1                                        DueProps        Atlanta
# 2                                       SalesLoft        Atlanta
# 5                                         REscour        Atlanta
# 6                                        viaCycle        Atlanta
# 9                                   Usable Health        Atlanta
# 11                                      OpenStudy        Atlanta
# 12                                         We&Co_        Atlanta
# 13                                           MOVL        Atlanta
# 14                                    Insightpool        Atlanta
# 15                                      TripLingo        Atlanta
# 17                                 Agency Spotter        Atlanta
# 18                                        BitPay         Atlanta
# ...

# %%
cities = df.groupby(by="city").count()

# %%
cities
# Out:
#                name  tagline  description
# city
# Atlanta        1141     1032         1050
# Austin         1580     1350         1384
# Bangalore      1861     1780         1757
# Berlin          960      832          848
# Boston         2090     1776         1819
# Boulder         400      299          308
# Chicago        1824     1607         1637
# Hong Kong       683      653          645
# Houston         623      474          492
# London         2338     2106         2122
# Los Angeles    4939     4331         4367
# Melbourne       584      545          538
# Montréal        692      637          629
# Moscow          640      585          581
# Munich          205      158          165
# New Delhi      1054     1004         1001
# New York       8146     6668         6846
# Paris          1103      920          911
# San Francisco  2326     2115         2151
# Santiago        503      482          483
# Sao Paulo       429      406          404
# ...

# %%
cities.sort_values('name',ascending=False)
# Out:
#                name  tagline  description
# city
# New York       8146     6668         6846
# Los Angeles    4939     4331         4367
# London         2338     2106         2122
# San Francisco  2326     2115         2151
# Boston         2090     1776         1819
# Bangalore      1861     1780         1757
# Chicago        1824     1607         1637
# Toronto        1811     1660         1653
# Austin         1580     1350         1384
# Washington DC  1169     1074         1086
# Atlanta        1141     1032         1050
# Seattle        1138      940          970
# Paris          1103      920          911
# New Delhi      1054     1004         1001
# Berlin          960      832          848
# Sydney          821      757          756
# Vancouver       821      705          714
# Tel Aviv        766      693          703
# Singapore       747      678          685
# Montréal        692      637          629
# Hong Kong       683      653          645
# ...

# %%
atx = df[df['city'] == 'Austin']

# %%
atx.sample(n=20)
# Out:
#                       name    city  \
# 2444            Globaloria  Austin
# 2180            PartingOut  Austin
# 1483              JumpUpon  Austin
# 2714              ZilloPay  Austin
# 1805       AlphaCloud Labs  Austin
# 2694         lindavista.tv  Austin
# 2289                 VUSIO  Austin
# 1762                Canopy  Austin
# 1569  DreamFunded of Texas  Austin
# 2008    Apple Energy Group  Austin
# 2345      Statified Sports  Austin
# 2410             Architect  Austin
# 1414            Martell TV  Austin
# 2460          AMD Ventures  Austin
# 2661             Crem8.com  Austin
# 2396             RevoStars  Austin
# 2211       HoopdieCars.com  Austin
# 2516            The Bureau  Austin
# 1868          FindAMassage  Austin
# 1544    General Governance  Austin
#
#                                                 tagline  \
# 2444            Learn CS-STEM through video game design
# 2180                       Virtual Online Salvage Yard
# ...
