# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
unfulfilled_dreams = "https://kinginstitute.stanford.edu/king-papers/documents/unfulfilled-dreams"
response = requests.get(unfulfilled_dreams)

# %%
page = response.text
soup = BeautifulSoup(page, "lxml").text
soup
# for element in soup.find_all(class_="group-transcription field-group-div"):
#     print(element.prettify())
# Out:
# ' \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"Unfulfilled Dreams" | The Martin Luther King, Jr., Research and Education Institute\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\nSkip to navigation\n\n\n\n\n\n\n\n SUNetID Login\n SUNetID Login \n\n\n\n\n\n\n\n\n\n\n\n   \n\n\n\nThe Martin Luther King, Jr.\nResearch and Education Institute\n\n\n\n\n\n\n\n\n\n\n\n\n \n  \nSearch form\n\nSearch \n\n\n\n\n\n \n\n\n\n Navigation menu    \n\n\n\n Main menu\n \nHome\nKing Papers About the Papers Project\nVolumes\nFeatured Documents\nSearch Documents\n\nLiberation Curriculum About the Liberation Curriculum\nPodcast\nLesson Plans\nAmerican Prophet: Online Course Companion\nCreate Your Own Classroom Activity\nClassroom Resources\nPartnerships\n\nKing Resources King Resources Overview\nKing Encyclopedia\nDocuments\nDocument Research Requests\nFreedom\'s Ring: King\'s "I Have a Dream" Speech\nMajor King Events Chronology\nKing Institute Publications\nRecom
# ...

# %%
speech = soup.find_all('p')
speech
# Out:
# [<p style="text-align:justify">I want to preach this morning from the subject: "Unfulfilled Dreams." "Unfulfilled Dreams." My text is taken from the eighth chapter of First Kings. Sometimes it’s overlooked. It is not one of the most familiar passages in the Old Testament. But I never will forget when I first came across it. It struck me as a passage having cosmic significance because it says so much in so few words about things that we all experience in life. David, as you know, was a great king. And the one thing that was foremost in David’s mind and in his heart was to build a great temple. The building of the temple was considered to be the most significant thing facing the Hebrew people, and the king was expected to bring this into being. David had the desire; he started.</p>,
# ...
