# %%
# !pip install Faker
import pandas as pd
import seaborn as sns
from faker import Faker
import random
# Out:
# Requirement already satisfied: Faker in /Users/toddhendricks/miniconda3/lib/python3.7/site-packages (4.1.1)
# Requirement already satisfied: text-unidecode==1.3 in /Users/toddhendricks/miniconda3/lib/python3.7/site-packages (from Faker) (1.3)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/toddhendricks/miniconda3/lib/python3.7/site-packages (from Faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in /Users/toddhendricks/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.4->Faker) (1.14.0)

# %%
fake = Faker()

# %%
name = [fake.name() for _ in range(1000)]

# %%
alpha = np.random.random_sample((1000,)) * 100
bravo = np.random.random_sample((1000,)) * 100
charlie = np.random.random_sample((1000,)) * 100
delta = np.random.random_sample((1000,)) * 100
alma_mater = np.random.choice(['Texas','Stanford','MIT','UCLA','Yale','Columbia','UNC','Berkeley','Harvard','Duke','Michighan','NYU','Princeton'],1000)
aura = np.random.choice(['Indigo','Periwinkle','Crimson','Infrared','Magenta','Silver','Black','Bronze','Gold','Beige','Emerald','Lime'],1000)
employer = [fake.bs() for _ in range(1000)]
experience = [random.randrange(3, 15, 1) for i in range(1000)]
diss = [fake.sentence() for _ in range(1000)]

# %%
a = {'Name' : name ,
     'A' : alpha, 
     'B': bravo,
     'C' : charlie,
     'D' : delta,
     'Alma Mater': alma_mater,
     'Aura' : aura,
     'Tag' : employer,
     'Experience' : experience, 
     'Dissertation' : diss
    }
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()

# %%
df.columns
# Out:
# Index(['Name', 'A', 'B', 'C', 'D', 'Alma Mater', 'Aura', 'Tag', 'Experience',
#        'Dissertation'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#                   Name         A        B        C         D Alma Mater  \
# 241       Chase Larsen   20.7471  24.7623  50.0125   55.3883  Michighan
# 105     Robert Hill MD   46.6617  31.2677  59.2968   59.6105   Columbia
# 689        Brett Clark   41.3941    57.03  28.5122    46.997      Texas
# 908       Erica Pruitt   38.3517  3.34873  27.3697   86.8293  Michighan
# 210  Danielle Thornton   21.0607  44.2153  93.6719   34.1869  Michighan
# 187    Jonathan Fields   37.4406  72.5627  43.9069   51.6164        UNC
# 923           Lisa Lee   55.4402  56.2256  52.7988  0.535669    Harvard
# 959     Jason Anderson   39.1594  96.6989  6.83566   32.2058   Berkeley
# 629   Kristy Jefferson  0.942633  8.85703  49.2433   76.2304        UNC
# 609        Dawn Rivers   18.8074  6.11841  25.4887   10.9163        NYU
#
#            Aura                             Tag Experience  \
# 241        Lime       reinvent B2C action-items         12
# 105       Black       iterate granular networks          4
# 689  Periwinkle     maximize enterprise vortals         10
# 908      Indigo   enable best-of-breed networks          7
# 210      Indigo      engineer B2B methodologies         10
# 187      Indigo  e-enable e-business e-commerce          7
# 923    Infrared      engage granular e-services         13
# 959    Infrared  benchmark extensible paradigms         10
# 629      Bronze   transition end-to-end systems          4
# 609      Silver      iterate cutting-edge users         10
#
#                                           Dissertation
# 241                     Several reveal different keep.
# 105  Finally practice lose difficult down project d...
# 689                         Our data school view deal.
# 908        Experience draw I conference third believe.
# 210   Opportunity born people note serious adult back.
# 187                Tough improve issue modern several.
# 923             Present recognize call doctor between.
# 959        Tree relate enjoy take amount final writer.
# 629  Opportunity final couple degree call middle hour.
# 609                   All drop movement listen better.

# %%
df = df.set_index(['Aura','Alma Mater'])

# %%
df.sample(5)
# Out:
#                                     Name        A        B        C        D  \
# Aura       Alma Mater
# Silver     Duke             Robert Mayer  46.9513  35.3078    28.79    83.65
# Periwinkle Princeton      Ashley Jackson  9.36744  23.1001  75.5404  75.2278
# Infrared   UCLA             Stephen Lynn  1.77303  60.9798  92.4674  78.9342
# Indigo     Texas             Mary Rivera  38.2848  33.9778  46.4108  73.8184
# Beige      UCLA        Mrs. Kayla Fisher  91.7124  56.0424  41.2427  95.6323
#
#                                                             Tag Experience  \
# Aura       Alma Mater
# Silver     Duke             re-intermediate open-source portals         11
# Periwinkle Princeton                   utilize dynamic eyeballs          8
# Infrared   UCLA                      seize granular experiences          5
# Indigo     Texas       re-intermediate transparent applications         12
# Beige      UCLA                     maximize distributed models         13
#
#                                                             Dissertation
# Aura       Alma Mater
# Silver     Duke                    Goal green contain condition various.
# Periwinkle Princeton             Pattern yourself spend performance may.
# Infrared   UCLA        Involve range security decide grow reveal buy ...
# Indigo     Texas          Collection fill season material after citizen.
# Beige      UCLA                           Lawyer over very just key way.

# %%
exp_df = df.sort_values(by=['Experience'],ascending=False)

# %%
exp_dfT = exp_df.transpose()

# %%
exp_dfT['Crimson']['Texas']
# Out:
# Alma Mater                                       Texas  \
# Name                                     Roger Collins
# A                                              92.7447
# B                                              37.6024
# C                                              89.3292
# D                                              32.6736
# Tag                 transform synergistic web services
# Experience                                          14
# Dissertation  Politics tough tonight seem simple high.
#
# Alma Mater                                  Texas  \
# Name                                Jessica Scott
# A                                         34.8173
# B                                         5.13694
# C                                         8.46152
# D                                         59.6229
# Tag              visualize cross-platform content
# Experience                                     14
# Dissertation  Challenge of own determine machine.
#
# Alma Mater                                  Texas  \
# Name                              Christopher Roy
# A                                         10.9987
# B                                         82.1977
# C                                          83.321
# D                                         24.9536
# Tag             envisioneer holistic partnerships
# Experience                                     13
# Dissertation  Prove even doctor moment take hand.
#
# Alma Mater                              Texas  \
# Name                              Shawn Smith
# A                                     24.9696
# B                                     23.3306
# C                                     3.36665
# D                                     35.9791
# Tag           whiteboard scalable initiatives
# Experience                                 12
# Dissertation  Particular special threat role.
#
# Alma Mater                                Texas  \
# Name                              Stephen Hicks
# A                                       82.3379
# B                                       25.8552
# C                                       75.1685
# D                                       89.2556
# Tag           streamline ubiquitous communities
# Experience                                   10
# Dissertation       Pressure major appear offer.
#
# Alma Mater                                   Texas  \
# Name                               Kristopher Reed
# A                                          15.3075
# B                                          75.2621
# C                                          49.4146
# D                                          15.5402
# Tag           iterate leading-edge functionalities
# Experience                                       9
# Dissertation      Many young reduce national trip.
#
# Alma Mater                          Texas  \
# Name                          Kurt Parker
# A                                 50.7658
# B                                 44.4173
# C                                 86.6967
# D                                 16.6832
# Tag           productize wireless markets
# Experience                              7
# Dissertation  Read money song raise pass.
#
# Alma Mater                                            Texas  \
# Name                                       Catherine Campos
# A                                                   27.3654
# B                                                   27.6967
# C                                                   13.2632
# D                                                   49.1985
# Tag                             scale interactive e-markets
# Experience                                                7
# Dissertation  Country tree fine white leader this attorney.
#
# Alma Mater                            Texas  \
# Name                           Richard Best
# A                                   8.42256
# B                                   69.5288
# C                                   86.9848
# D                                   91.2736
# Tag                   leverage sexy metrics
# Experience                                5
# Dissertation  Art early his success forget.
#
# Alma Mater                                                Texas  \
# Name                                              Alexandra Lee
# A                                                       62.6092
# B                                                       91.6642
# C                                                       91.7773
# D                                                       78.3727
# Tag                        re-contextualize efficient paradigms
# Experience                                                    4
# Dissertation  Rule piece reflect coach become military see h...
#
# Alma Mater                             Texas
# Name                          Steven Gardner
# A                                    39.4644
# B                                     4.3649
# C                                    37.4926
# D                                    9.30423
# Tag           streamline magnetic e-services
# Experience                                 4
# Dissertation             Service cause late.

# %%
sns.distplot(df['Experience'],bins=25)

# %%
df['A'] = df['A'].astype(float)
df.groupby(['Alma Mater'])['A'].mean().sort_values()
# Out:
# Alma Mater
# Yale         45.574812
# Texas        46.740621
# UCLA         47.249662
# Princeton    47.268939
# Columbia     48.180779
# Stanford     48.485176
# Harvard      48.751543
# UNC          48.974010
# Berkeley     50.491744
# MIT          51.841444
# Michighan    53.128741
# Duke         53.400486
# NYU          59.965709
# Name: A, dtype: float64

# %%
df.columns
# Out:
# Index(['Name', 'A', 'B', 'C', 'D', 'Tag', 'Experience', 'Dissertation'], dtype='object')

# %%
senior = df[df['Experience'] > 12]

# %%
senior.shape
# Out:
# (170, 8)

# %%
sns.distplot(senior['B'])

# %%
practice_df = df.sample(20)

# %%
practice_df.head(3)
# Out:
#                              Name          A        B        C        D  \
# Aura    Alma Mater
# Bronze  Duke        Barbara Doyle  99.101363  75.6594  91.1516  23.9955
# Beige   NYU           Kelly Smith  29.496526  87.5945  6.11126   20.294
# Crimson Yale         Tracy Carter  91.132356  5.79266    17.53  33.4957
#
#                                                         Tag Experience  \
# Aura    Alma Mater
# Bronze  Duke                    transform real-time schemas          8
# Beige   NYU         re-contextualize e-business experiences         14
# Crimson Yale                    extend holistic initiatives         13
#
#                                           Dissertation
# Aura    Alma Mater
# Bronze  Duke        Type bad environmental sort catch.
# Beige   NYU             Attorney summer accept modern.
# Crimson Yale                     Ball win next energy.

# %%
practice_df = practice_df.reset_index()
practice_df.columns
# Out:
# Index(['Aura', 'Alma Mater', 'Name', 'A', 'B', 'C', 'D', 'Tag', 'Experience',
#        'Dissertation'],
#       dtype='object')

# %%
pivoted = practice_df.pivot(index='Name', columns='Aura', values='A')
pivoted
# Out:
# Aura                   Beige      Black     Bronze    Crimson   Emerald  \
# Name
# Alec Mitchell            NaN        NaN        NaN        NaN       NaN
# Amanda Holt              NaN        NaN        NaN        NaN       NaN
# Ashley Jackson           NaN        NaN        NaN        NaN       NaN
# Barbara Doyle            NaN        NaN  99.101363        NaN       NaN
# Benjamin Martinez        NaN        NaN        NaN        NaN       NaN
# David Erickson           NaN  80.246651        NaN        NaN       NaN
# David Parker       31.967263        NaN        NaN        NaN       NaN
# Dylan Mcdaniel           NaN        NaN        NaN        NaN       NaN
# Jeffrey Thomas           NaN        NaN        NaN        NaN       NaN
# Jessica Johnson          NaN        NaN        NaN        NaN       NaN
# Joy Blevins              NaN        NaN        NaN        NaN       NaN
# Kelly Smith        29.496526        NaN        NaN        NaN       NaN
# Laura Brown              NaN        NaN        NaN        NaN       NaN
# Ms. Taylor Kent          NaN  13.982557        NaN        NaN       NaN
# Nichole Stanley          NaN        NaN        NaN        NaN       NaN
# Pamela Esparza           NaN        NaN        NaN        NaN       NaN
# Paul Cruz                NaN        NaN        NaN        NaN       NaN
# Thomas Chapman           NaN        NaN        NaN        NaN  4.427074
# Tracy Carter             NaN        NaN        NaN  91.132356       NaN
# Tracy Walsh              NaN        NaN        NaN        NaN  2.060505
#
# Aura                    Gold     Indigo   Infrared       Lime    Magenta  \
# Name
# Alec Mitchell            NaN        NaN  39.988803        NaN        NaN
# Amanda Holt              NaN        NaN        NaN        NaN  55.116200
# Ashley Jackson           NaN        NaN        NaN        NaN        NaN
# Barbara Doyle            NaN        NaN        NaN        NaN        NaN
# Benjamin Martinez        NaN        NaN        NaN        NaN        NaN
# David Erickson           NaN        NaN        NaN        NaN        NaN
# David Parker             NaN        NaN        NaN        NaN        NaN
# Dylan Mcdaniel           NaN        NaN        NaN  90.056816        NaN
# Jeffrey Thomas           NaN        NaN        NaN        NaN  27.468050
# Jessica Johnson          NaN  93.633041        NaN        NaN        NaN
# Joy Blevins              NaN  38.569969        NaN        NaN        NaN
# Kelly Smith              NaN        NaN        NaN        NaN        NaN
# Laura Brown        60.980711        NaN        NaN        NaN        NaN
# Ms. Taylor Kent          NaN        NaN        NaN        NaN        NaN
# Nichole Stanley     0.650375        NaN        NaN        NaN        NaN
# Pamela Esparza           NaN        NaN        NaN        NaN  89.677231
# Paul Cruz                NaN        NaN        NaN        NaN        NaN
# Thomas Chapman           NaN        NaN        NaN        NaN        NaN
# Tracy Carter             NaN        NaN        NaN        NaN        NaN
# Tracy Walsh              NaN        NaN        NaN        NaN        NaN
#
# Aura               Periwinkle     Silver
# Name
# Alec Mitchell             NaN        NaN
# Amanda Holt               NaN        NaN
# Ashley Jackson       9.367437        NaN
# Barbara Doyle             NaN        NaN
# Benjamin Martinez         NaN  15.947009
# David Erickson            NaN        NaN
# David Parker              NaN        NaN
# Dylan Mcdaniel            NaN        NaN
# Jeffrey Thomas            NaN        NaN
# Jessica Johnson           NaN        NaN
# Joy Blevins               NaN        NaN
# Kelly Smith               NaN        NaN
# Laura Brown               NaN        NaN
# Ms. Taylor Kent           NaN        NaN
# Nichole Stanley           NaN        NaN
# Pamela Esparza            NaN        NaN
# Paul Cruz                 NaN  94.544120
# Thomas Chapman            NaN        NaN
# Tracy Carter              NaN        NaN
# Tracy Walsh               NaN        NaN
