# %%
# !pip install Faker
import pandas as pd
import seaborn as sns
from faker import Faker
import random
# Out:
# Requirement already satisfied: Faker in /Users/toddhendricks/miniconda3/lib/python3.7/site-packages (4.1.1)
# Requirement already satisfied: text-unidecode==1.3 in /Users/toddhendricks/miniconda3/lib/python3.7/site-packages (from Faker) (1.3)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/toddhendricks/miniconda3/lib/python3.7/site-packages (from Faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in /Users/toddhendricks/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.4->Faker) (1.14.0)

# %%
fake = Faker()

# %%
name = [fake.name() for _ in range(1000)]

# %%
alpha = np.random.random_sample((1000,)) * 100
bravo = np.random.random_sample((1000,)) * 100
charlie = np.random.random_sample((1000,)) * 100
delta = np.random.random_sample((1000,)) * 100
alma_mater = np.random.choice(['Texas','Stanford','MIT','UCLA','Yale','Columbia','UNC','Berkeley','Harvard','Duke','Michighan','NYU','Princeton'],1000)
aura = np.random.choice(['Indigo','Periwinkle','Crimson','Infrared','Magenta','Silver','Black','Bronze','Gold','Beige','Emerald','Lime'],1000)
employer = [fake.bs() for _ in range(1000)]
experience = [random.randrange(3, 15, 1) for i in range(1000)]
diss = [fake.sentence() for _ in range(1000)]

# %%
a = {'Name' : name ,
     'A' : alpha, 
     'B': bravo,
     'C' : charlie,
     'D' : delta,
     'Alma Mater': alma_mater,
     'Aura' : aura,
     'Tag' : employer,
     'Experience' : experience, 
     'Dissertation' : diss
    }
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()

# %%
df.columns
# Out:
# Index(['Name', 'A', 'B', 'C', 'D', 'Alma Mater', 'Aura', 'Tag', 'Experience',
#        'Dissertation'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#                   Name        A        B         C        D Alma Mater  \
# 163   Elizabeth Graves  38.8004  86.6497   5.01217  50.5235   Berkeley
# 227     Michael Mendez  60.5731  48.5798   45.0015   80.564  Michighan
# 332      Shelly Walker  87.7346  1.62547   31.6662  39.1818   Columbia
# 176       Monica Barry   21.252  43.4576   3.64264  2.02375        MIT
# 109        Mary Austin   94.155  39.6754   11.4106  67.1639        MIT
# 895  William Alexander  58.3557  9.21042   43.5257  34.3193       Yale
# 871      Henry Aguilar  58.0836  61.0554   54.5237  41.5463       Yale
# 968     Yesenia Harvey  85.2213  92.6202   94.6571  86.3976    Harvard
# 671     Gabriel Pierce  50.4139  92.6057  0.600553  17.3581        NYU
# 766        Laurie Ward  54.4755  69.5896   9.74532  83.3585    Harvard
#
#            Aura                                Tag Experience  \
# 163        Gold               exploit sexy content          5
# 227      Bronze       transition real-time markets          6
# 332    Infrared  enable innovative infrastructures         11
# 176    Infrared       brand proactive technologies          5
# 109  Periwinkle  target out-of-the-box communities          6
# 895    Infrared     utilize leading-edge e-markets         12
# 871      Bronze                empower rich models         10
# 968      Indigo      e-enable virtual applications          5
# 671        Lime            e-enable enterprise ROI          8
# 766  Periwinkle         empower magnetic mindshare         11
#
#                                           Dissertation
# 163                             Any manage woman wall.
# 227                            System model under son.
# 332                         Seven enjoy begin clearly.
# 176                           Production speak become.
# 109                        Matter protect these water.
# 895  Continue where structure under challenge here ...
# 871                             Like instead national.
# 968             Hotel together material affect course.
# 671          Stay newspaper thousand respond economic.
# 766                           Stuff across stock view.

# %%
df = df.set_index(['Aura','Alma Mater'])

# %%
df.sample(5)
# Out:
#                                       Name        A        B        C  \
# Aura    Alma Mater
# Gold    NYU           Christopher Thompson  71.6117  95.5041  17.9688
# Lime    Harvard              Anthony Silva  2.06961  26.3627  93.1483
# Magenta MIT                 Christopher Le  35.1973  60.9675  13.0729
# Crimson UNC         Elizabeth Reynolds DDS  96.9672  56.8337  9.72706
# Beige   Berkeley            Jonathan Evans  61.6252  8.18916  27.0646
#
#                           D                             Tag Experience  \
# Aura    Alma Mater
# Gold    NYU         89.7618       embrace proactive content          7
# Lime    Harvard     59.2691   synthesize end-to-end markets         11
# Magenta MIT         82.8826  repurpose sticky relationships         14
# Crimson UNC         95.8278   deploy proactive deliverables          7
# Beige   Berkeley    36.5797      enhance ubiquitous content         14
#
#                                                 Dissertation
# Aura    Alma Mater
# Gold    NYU                   Financial provide goal look a.
# Lime    Harvard     Or program significant certainly expert.
# Magenta MIT                Though democratic huge area cost.
# Crimson UNC                       Late lot dream television.
# Beige   Berkeley          Up billion so center card capital.

# %%
exp_df = df.sort_values(by=['Experience'],ascending=False)

# %%
exp_dfT = exp_df.transpose()

# %%
exp_dfT['Crimson']['Texas']
# Out:
# Alma Mater                              Texas  \
# Name                             Mark Wallace
# A                                     73.5867
# B                                     64.8279
# C                                     87.1308
# D                                     12.3149
# Tag           seize next-generation solutions
# Experience                                 14
# Dissertation              Animal let than TV.
#
# Alma Mater                              Texas  \
# Name                              Daniel Cook
# A                                     80.6615
# B                                     83.1743
# C                                     79.7935
# D                                     21.8009
# Tag           syndicate user-centric channels
# Experience                                 10
# Dissertation           Near his garden coach.
#
# Alma Mater                                                Texas  \
# Name                                               Brian Jensen
# A                                                       81.4416
# B                                                       37.5189
# C                                                       70.5108
# D                                                       9.63748
# Tag                   transition mission-critical supply-chains
# Experience                                                    8
# Dissertation  High final conference weight financial bank food.
#
# Alma Mater                              Texas                           Texas  \
# Name                          Daniel Williams                 Michael Jackson
# A                                     11.3191                         72.2827
# B                                     42.0034                         5.51524
# C                                     90.0549                         41.2838
# D                                     97.2634                         85.6585
# Tag           incubate strategic applications  syndicate vertical initiatives
# Experience                                  7                               6
# Dissertation     Brother answer maybe doctor.         Arm team mean song big.
#
# Alma Mater                         Texas                              Texas  \
# Name                    Christian Miller                   Patricia Sanders
# A                                48.0313                            44.0017
# B                                1.32576                             12.651
# C                                38.3107                             29.488
# D                                76.0603                            14.0553
# Tag           incubate holistic eyeballs     strategize distributed schemas
# Experience                             6                                  3
# Dissertation     Perform to high family.  Will least fund win material own.
#
# Alma Mater                       Texas
# Name                    Breanna Galvan
# A                              32.2681
# B                              9.92923
# C                              96.3635
# D                              46.7614
# Tag           matrix intuitive portals
# Experience                           3
# Dissertation          Glass mind blue.

# %%
sns.distplot(df['Experience'],bins=25)

# %%
df['A'] = df['A'].astype(float)
df.groupby(['Alma Mater'])['A'].mean().sort_values()
# Out:
# Alma Mater
# Harvard      43.509182
# Princeton    47.516396
# Columbia     48.101258
# Texas        49.832921
# Berkeley     50.086700
# Michighan    50.145522
# MIT          50.260381
# UNC          51.877372
# Yale         51.933403
# NYU          52.118226
# Duke         52.552705
# UCLA         54.284916
# Stanford     56.407294
# Name: A, dtype: float64

# %%
df.columns
# Out:
# Index(['Name', 'A', 'B', 'C', 'D', 'Tag', 'Experience', 'Dissertation'], dtype='object')

# %%
senior = df[df['Experience'] > 12]

# %%
senior.shape
# Out:
# (186, 8)

# %%
sns.distplot(senior['B'])

# %%
df.head(5)
# Out:
#                                Name          A        B        C        D  \
# Aura     Alma Mater
# Infrared Harvard      Joseph Warren   9.077906  50.1102  90.8675  8.50468
# Beige    MIT             Dana Jones  21.637580  56.7015  97.5177  34.8577
# Emerald  Stanford    Michael Cooper  26.835614   55.419  90.6773   70.269
# Indigo   UCLA             Leah Webb  99.440798  64.2248  91.1312  17.7528
# Black    Texas        Yesenia Adams  16.159768  82.7161  55.0465  68.5163
#
#                                                             Tag Experience  \
# Aura     Alma Mater
# Infrared Harvard                     seize world-class channels         12
# Beige    MIT              productize web-enabled info-mediaries         14
# Emerald  Stanford              architect cross-platform schemas          6
# Indigo   UCLA        synthesize next-generation infrastructures          8
# Black    Texas                      scale dynamic architectures         13
#
#                                           Dissertation
# Aura     Alma Mater
# Infrared Harvard                    Land staff nearly.
# Beige    MIT                    Poor three ahead firm.
# Emerald  Stanford              Worker join at end off.
# Indigo   UCLA         Study simply heart study person.
# Black    Texas       Road these Democrat break affect.

# %%
bullshit = df[df['Tag'].str.contains('leverage|synergy')].reset_index()

# %%
pivot_bs = df.pivot(index='date', columns='variable', values='value')
# Out:
#           Aura Alma Mater             Name          A        B        C  \
# 0       Bronze   Berkeley  Robert Petersen   0.337373   30.856  68.5514
# 1      Crimson  Princeton    Sydney Burton  32.226500   82.012  70.7894
# 2         Gold   Stanford  Zachary Johnson  62.282150  65.9213  18.5189
# 3      Crimson   Columbia      Adam Bishop  51.886857  23.3877  68.4202
# 4      Magenta      Texas     David Harvey  21.173427  94.3036  48.5468
# 5         Lime  Michighan      Dale Cooper  43.346260   73.281  48.3938
# 6   Periwinkle   Berkeley      Chad Fowler  52.051120  28.2356  31.7027
# 7     Infrared  Princeton    Belinda Downs  34.427411  27.0553  62.3433
# 8         Gold       UCLA  Gabriel Shaffer  90.206525  31.4947  95.8706
# 9      Emerald       Yale     John Stewart  41.294824  36.8523  85.0842
# 10       Black  Michighan    Alexis Steele  41.575457  21.8647  71.8473
# 11        Gold  Michighan    Anthony Myers  41.162057  53.7033  62.5523
# 12  Periwinkle       Duke      Ronald Vega  34.862484  74.2512  68.3452
# 13      Indigo      Texas  Paula Hernandez   0.258773  85.3123  85.1147
# 14       Black        MIT   Matthew Garcia  83.489948  23.1665  47.9315
# 15        Lime      Texas     Scott Wright  37.510834  69.5209  53.4459
#
#           D                                 Tag Experience  \
# 0   96.0174        leverage distributed systems         13
# 1   25.0891     leverage world-class e-business          9
# 2   58.8506          leverage sexy applications          4
# 3    56.812      leverage dynamic web-readiness         13
# 4   23.4909          leverage global e-services          3
# 5   59.2673  leverage open-source supply-chains          6
# 6   27.8396               leverage 24/7 content          6
# 7   35.0615   leverage e-business web-readiness         13
# 8   98.7601           leverage holistic systems          6
# 9   21.2606   leverage open-source partnerships          6
# 10  61.7098             leverage global schemas         10
# 11   65.138     leverage frictionless e-markets         12
# 12  73.3698      leverage magnetic partnerships          8
# 13  99.2742        leverage strategic solutions         11
# 14  62.2843           leverage back-end content         12
# 15  15.3597          leverage global interfaces         10
#
#                                          Dissertation
# 0                               Film level while oil.
# 1                 Capital peace wait region specific.
# 2                      Moment material strategy line.
# 3                  Behavior list drive child contain.
# 4       Than nothing number design natural exist lay.
# 5          More manage around style until program he.
# 6                                Keep us hair result.
# 7         Head rate finally people whom west measure.
# 8     Everyone add good condition cause wish prepare.
# 9   Second opportunity need matter fish through th...
# 10                         Which simple with nothing.
# 11                   For use any physical exactly as.
# 12               Single language quite free and poor.
# 13  Interview exactly risk religious market onto r...
# 14                      He here memory subject plant.
# 15                      Training admit up talk about.

# %%
longhorns.columns
# Out:
# Index(['Name', 'A', 'B', 'C', 'D', 'Alma Mater', 'Tag', 'Experience',
#        'Dissertation'],
#       dtype='object')

# %%
longhorns.sort_values('A')
# Out:
#                           Name        A        B        C        D Alma Mater  \
# Aura
# Emerald        Edwin Price DDS  1.40268  66.6466  65.5073  34.3486      Texas
# Gold             Sarah Esparza  1.79159  78.9075  65.9505   19.973      Texas
# Silver             Megan Lopez  3.90541  61.0341    62.67  28.1225      Texas
# Gold             Jonathan Ruiz   6.6563  48.9128  6.32885  63.7711      Texas
# Periwinkle      Richard Sutton  7.63518  44.9256  80.5631  8.36159      Texas
# ...                        ...      ...      ...      ...      ...        ...
# Crimson       Michelle Johnson  90.9375  6.72337  24.3964  32.5899      Texas
# Crimson            Holly Lyons  91.9813  56.4996  61.1386    59.72      Texas
# Crimson           Barry Monroe   92.483  2.38666  53.5122  3.87468      Texas
# Bronze      Miranda Washington  98.5592  93.7879  25.7185  59.9491      Texas
# Emerald         Kathleen Hines  99.9331  41.6462  45.4949  98.9833      Texas
#
#                                             Tag Experience  \
# Aura
# Emerald     maximize next-generation interfaces          7
# Gold                    mesh compelling metrics         13
# Silver          synergize compelling e-services          9
# Gold             facilitate dot-com communities          3
# Periwinkle                empower real-time ROI          6
# ...                                         ...        ...
# Crimson                 drive dynamic paradigms          8
# Crimson               grow cross-media channels         14
# Crimson               morph scalable e-services          7
# Bronze            exploit cross-media e-tailers          7
# Emerald                   generate 24/365 users          8
#
#                                                  Dissertation
# Aura
# Emerald                        Your prepare thought share if.
# Gold                         Responsibility team market task.
# Silver                Poor consumer during charge group wind.
# Gold        Challenge say their skin drive alone attack wa...
# Periwinkle                              Guess walk look east.
# ...                                                       ...
# Crimson                               Role manager half girl.
# Crimson        Doctor use maybe health personal view respond.
# Crimson     Natural response member true goal company trou...
# Bronze               Three computer everybody grow word when.
# Emerald               Rest accept too civil wind public drug.
#
# [68 rows x 9 columns]

# %%
# Kathleen Hines is a rockstar
