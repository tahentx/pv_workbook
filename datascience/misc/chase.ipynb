# %%
import pandas as pd

# %%
df = pd.read_csv('chase2020.csv')
df.head(10)
# Out:
#   Transaction Date   Post Date             Description           Category  \
# 0       06/04/2020  06/05/2020          APPLE.COM/BILL           Shopping
# 1       06/01/2020  06/02/2020                 NYTIMES  Bills & Utilities
# 2       06/01/2020  06/02/2020   AT&amp;T*BILL PAYMENT  Bills & Utilities
# 3       06/01/2020  06/01/2020       Audible*MY0H793W1  Bills & Utilities
# 4       05/31/2020  06/01/2020   DOORDASH*URBAN PLATES       Food & Drink
# 5       05/28/2020  05/31/2020                  BAAGAN       Food & Drink
# 6       05/31/2020  05/31/2020           TFK OLO #1015       Food & Drink
# 7       05/25/2020  05/28/2020  SPROUTS FARMERS MARSSS          Groceries
# 8       05/25/2020  05/27/2020     SPROUTS FARMERS MAR          Groceries
# 9       05/25/2020  05/27/2020     SPROUTS FARMERS MAR          Groceries
#
#      Type  Amount
# 0    Sale   -0.99
# 1    Sale  -16.00
# 2    Sale  -69.00
# 3    Sale  -14.95
# 4    Sale  -46.28
# 5    Sale  -33.82
# ...

# %%
personal = df[df['Category'] == 'Personal']

# %%
nyt = df[df['Description'] == 'NYTIMES']

# %%
nyt
# Out:
#    Transaction Date   Post Date Description           Category  Type  Amount
# 1        06/01/2020  06/02/2020     NYTIMES  Bills & Utilities  Sale   -16.0
# 30       05/02/2020  05/03/2020     NYTIMES  Bills & Utilities  Sale   -16.0
# 63       04/02/2020  04/03/2020     NYTIMES  Bills & Utilities  Sale   -16.0
