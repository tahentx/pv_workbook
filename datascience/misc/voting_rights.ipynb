# %%
import pandas as pd

# %%
df = pd.read_csv('ga_registered_voters.csv')

# %%
# clean columns
df.columns = map(str.lower, df.columns)
df.columns = df.columns.str.strip() 
df.columns = df.columns.str.replace('        ', ' ')
df.columns = df.columns.str.replace(' ', '_')

# %%
blk_wmn = df.sort_values('bh_____female_voters', ascending=False)

# %%
df['gender_gap'] = df['bh_____female_voters'] - df['bh_____male_voters']

# %%
gap = df.sort_values('gender_gap', ascending=False)

# %%
gap
# Out:
#           county_id county_name  ai__male__voters  ai_female_voters  \
# 159  GRAND TOTALS:          NaN              8346              8291
# 43              044      DEKALB               673               672
# 59              060      FULTON               966               902
# 32              033        COBB               668               673
# 66              067    GWINNETT               786               771
# ..              ...         ...               ...               ...
# 130             131  TALIAFERRO                 0                 0
# 104             105      MURRAY                20                18
# 92              093     LUMPKIN                66                43
# 41              042      DAWSON                26                37
# 5               006       BANKS                15                11
#
#      ai_unknown_voters  ap____male__voters  ap_female_voters  \
# 159                 52               92511            102307
# ...

# %%
pct = pd.read_csv('/Users/toddhendricks/Downloads/2016-precinct-president.csv')
# Out:
# /Users/toddhendricks/miniconda3/envs/dagster/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (13,17,19,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
ga = pct[pct.state == 'Georgia']
ga.columns
# Out:
# Index(['year', 'stage', 'special', 'state', 'state_postal', 'state_fips',
#        'state_icpsr', 'county_name', 'county_fips', 'county_ansi',
#        'county_lat', 'county_long', 'jurisdiction', 'precinct', 'candidate',
#        'candidate_normalized', 'office', 'district', 'writein', 'party',
#        'mode', 'votes', 'candidate_opensecrets', 'candidate_wikidata',
#        'candidate_party', 'candidate_last', 'candidate_first',
#        'candidate_middle', 'candidate_full', 'candidate_suffix',
#        'candidate_nickname', 'candidate_fec', 'candidate_fec_name',
#        'candidate_google', 'candidate_govtrack', 'candidate_icpsr',
#        'candidate_maplight'],
#       dtype='object')

# %%
cols = ['county_name','precinct','candidate_fec_name','candidate_party','votes']

# %%
fulton = ga[ga.county_name == 'Fulton County']
fulton = fulton[cols]

# %%
fulton.candidate_fec_name = fulton.candidate_fec_name.str.replace('CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE', 'hrc').str.replace('TRUMP, DONALD J. / MICHAEL R. PENCE', 'trump')
# Out:
# <ipython-input-86-6299ee97f30b>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   fulton.candidate_fec_name = fulton.candidate_fec_name.str.replace('CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE', 'hrc').str.replace('TRUMP, DONALD J. / MICHAEL R. PENCE', 'trump')

# %%
fulton = fulton[fulton.candidate_fec_name == ('hrc' or 'trump')]
fulton = fulton.sort_values('votes', ascending=False)
fulton.head(10)
# Out:
#           county_name  county_fips precinct candidate_fec_name  \
# 590662  Fulton County      13121.0    FA01A                hrc
# 591322  Fulton County      13121.0     SC15                hrc
# 591910  Fulton County      13121.0    UC02A                hrc
# 591382  Fulton County      13121.0    SC18B                hrc
# 589258  Fulton County      13121.0      06D                hrc
# 591154  Fulton County      13121.0    SC07A                hrc
# 591334  Fulton County      13121.0     SC16                hrc
# 590626  Fulton County      13121.0     EP03                hrc
# 591082  Fulton County      13121.0    SC01B                hrc
# 589990  Fulton County      13121.0      11B                hrc
#
#         candidate_party  votes
# 590662              NaN   3056
# 591322              NaN   3028
# 591910              NaN   2709
# 591382              NaN   2657
# 589258              NaN   2491
# 591154              NaN   2358
# 591334              NaN   2230
# ...

# %%
# Out:
# precinct   candidate_fec_name
# 01A        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE    1898
#            JOHNSON, JOHN FITZGERALD MR.                         97
#            TRUMP, DONALD J. / MICHAEL R. PENCE                 173
# 01B        CLINTON, HILLARY RODHAM / TIMOTHY MICHAEL KAINE    2304
#            JOHNSON, JOHN FITZGERALD MR.                        125
#                                                               ...
# Write-ins  FOX, CHERUNDA LYNN                                    3
#            MCMULLIN, EVAN / MINDY FINN                         409
#            SMITH, RYAN                                           2
#            STEIN, JILL                                         361
#            WILSON, WILLIE                                        3
# Name: votes, Length: 1045, dtype: int64
