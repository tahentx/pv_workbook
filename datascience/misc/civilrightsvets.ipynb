# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
main_url = 'https://www.crmvet.org/vet/vethome.htm'

def scrape_page_data(site):
    response = requests.get(site)
    soup = BeautifulSoup(response.text)
    return soup

soup = scrape_page_data(main_url)

# %%
def get_individual_page_links(doc):
    return [link.get('href') for link in soup.find_all('a')]

# %%
members = soup.find_all('a')

# %%
type(members)
# Out:
# bs4.element.ResultSet

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <html>
# <head>
# <meta content="Civil Rights Movement veterans
# background and contact information." name="description"/>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-10945079-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Roll Call of Civil Rights Movement Veterans</title>
# <meta content="Roll call of Civil Rights Movement veterans
# (CORE, NAACP, SCLC, SNCC, and similar organizations)" name="description"/>
# <meta content="Archive of Civil Rights Movement,
# Southern Freedom Movement, Student Nonviolent Coordinating
# ...

# %%
orgs = ['CORE', 'NAACP', 'SCLC', 'SNCC', 'SCEF', 'SSOC', 'Delta Ministry', 'Deacons for Defense']

# %%
def create_members_df(data, df = pd.DataFrame()):
    members = data.find_all('li')
    members = list(members[45:])
    for member in members:
        print(member)
#         member = str(member).split(">")
#         df['name'], df['campaign'], df['residence'] = member[2],member[3],member[4]
    return df

create_members_df(soup)
# Out:
# <li><a href="adamsj.htm">Jane Adams</a> - COFO, 1964-65,
# MS<br/>
# [Carbondale, IL]
#
# <p></p></li>
# <li><a href="adamsfj.htm">Frankye Adams-Johnson</a> - NAACP, SNCC,
# MS, 1963-1967<br/>
# [Jackson, MS]
#
# <p>
# </p></li>
# <li><a href="adickes.htm">Sandra Adickes</a> - SNCC 1963-64,
# MS<br/>
# [Dayton, NJ]
#
# <p>
# </p></li>
# <li><a href="adlerl.htm">Lynn Adler</a> - SCLC, SCOPE, AL, IL<br/>
# [Berkeley, CA]
#
# <p>
# </p></li>
# <li><a href="adler.htm">Margot Adler</a> - SNCC/MFDP 1965, MS.<br/>
# [New York, NY]
#
# <p>
# </p></li>
# <li><a href="aelony.htm">Zev Aelony</a> - CORE 1959-65, AL, GA,
# FL<br/>
# [Minneapolis, MN]
#
# <p>
# </p></li>
# <li><a href="albertzg.htm">George Albertz</a> - MFDP, SNCC, 1964-65,
# MS<br/>
# [Rifton, NY]
#
# <p>
# </p></li>
# <li><a href="chude.htm">Chude Pam Parker Allen</a> - 1964 Freedom
# Summer, MS.<br/>
# [San Francisco, CA]
#
# <p></p></li>
# <li><a href="allisn.htm">Nicholas (Nick) Allis</a> - COFO,
# 1964, MS<br/>
# ...
