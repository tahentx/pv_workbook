# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('chase2020.csv')

# %%
df
# Out:
#     Transaction Date   Post Date             Description           Category  \
# 0         06/04/2020  06/05/2020          APPLE.COM/BILL           Shopping
# 1         06/01/2020  06/02/2020                 NYTIMES  Bills & Utilities
# 2         06/01/2020  06/02/2020   AT&amp;T*BILL PAYMENT  Bills & Utilities
# 3         06/01/2020  06/01/2020       Audible*MY0H793W1  Bills & Utilities
# 4         05/31/2020  06/01/2020   DOORDASH*URBAN PLATES       Food & Drink
# ..               ...         ...                     ...                ...
# 152       01/12/2020  01/13/2020     CVS/PHARMACY #09378  Health & Wellness
# 153       01/11/2020  01/12/2020     PATRICK WHALEN  PHD  Health & Wellness
# 154       01/04/2020  01/05/2020           MICROVENTURES           Personal
# 155       01/03/2020  01/05/2020  NEW YORK TIMES DIGITAL  Bills & Utilities
# 156       01/02/2020  01/05/2020            SAFEWAY #638          Groceries
#
#      Type  Amount
# 0    Sale   -0.99
# 1    Sale  -16.00
# 2    Sale  -69.00
# 3    Sale  -14.95
# 4    Sale  -46.28
# ..    ...     ...
# 152  Sale  -38.82
# 153  Sale -260.00
# 154  Sale -207.00
# 155  Sale  -16.00
# 156  Sale  -26.31
#
# [157 rows x 6 columns]

# %%
by_category = df.groupby(['Category'])['Amount'].count()

# %%
cat_counts = by_category.sort_values()

# %%
x = sns.barplot(x=cat_counts.index,y=cat_counts.values)
x.set_xticklabels(x.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, 'Automotive'),
#  Text(0, 0, 'Education'),
#  Text(0, 0, 'Professional Services'),
#  Text(0, 0, 'Gas'),
#  Text(0, 0, 'Personal'),
#  Text(0, 0, 'Travel'),
#  Text(0, 0, 'Fees & Adjustments'),
#  Text(0, 0, 'Health & Wellness'),
#  Text(0, 0, 'Bills & Utilities'),
#  Text(0, 0, 'Shopping'),
#  Text(0, 0, 'Groceries'),
#  Text(0, 0, 'Food & Drink')]

# %%
df
# Out:
#     Transaction Date   Post Date             Description           Category  \
# 0         06/04/2020  06/05/2020          APPLE.COM/BILL           Shopping
# 1         06/01/2020  06/02/2020                 NYTIMES  Bills & Utilities
# 2         06/01/2020  06/02/2020   AT&amp;T*BILL PAYMENT  Bills & Utilities
# 3         06/01/2020  06/01/2020       Audible*MY0H793W1  Bills & Utilities
# 4         05/31/2020  06/01/2020   DOORDASH*URBAN PLATES       Food & Drink
# ..               ...         ...                     ...                ...
# 152       01/12/2020  01/13/2020     CVS/PHARMACY #09378  Health & Wellness
# 153       01/11/2020  01/12/2020     PATRICK WHALEN  PHD  Health & Wellness
# 154       01/04/2020  01/05/2020           MICROVENTURES           Personal
# 155       01/03/2020  01/05/2020  NEW YORK TIMES DIGITAL  Bills & Utilities
# 156       01/02/2020  01/05/2020            SAFEWAY #638          Groceries
#
#      Type  Amount
# 0    Sale   -0.99
# 1    Sale  -16.00
# 2    Sale  -69.00
# 3    Sale  -14.95
# 4    Sale  -46.28
# ..    ...     ...
# 152  Sale  -38.82
# 153  Sale -260.00
# 154  Sale -207.00
# 155  Sale  -16.00
# 156  Sale  -26.31
#
# [157 rows x 6 columns]

# %%
total_fees = fees['Amount'].sum()
total_spend = df['Amount'].sum()
pct_fees = total_fees / total_spend
pct_fees
# Out:
# 0.12942120933422704

# %%
df['Description'] = df['Description'].apply(lambda x : 'door dash' if 'DOORDASH' in x else x)
# df.sport.apply(lambda x: 'ball sport' if 'ball' in x else x)

# %%
df['Amount'] = df['Amount'] * -1

# %%
df
# Out:
#     Transaction Date   Post Date             Description           Category  \
# 0         06/04/2020  06/05/2020          APPLE.COM/BILL           Shopping
# 1         06/01/2020  06/02/2020                 NYTIMES  Bills & Utilities
# 2         06/01/2020  06/02/2020   AT&amp;T*BILL PAYMENT  Bills & Utilities
# 3         06/01/2020  06/01/2020       Audible*MY0H793W1  Bills & Utilities
# 4         05/31/2020  06/01/2020               door dash       Food & Drink
# ..               ...         ...                     ...                ...
# 152       01/12/2020  01/13/2020     CVS/PHARMACY #09378  Health & Wellness
# 153       01/11/2020  01/12/2020     PATRICK WHALEN  PHD  Health & Wellness
# 154       01/04/2020  01/05/2020           MICROVENTURES           Personal
# 155       01/03/2020  01/05/2020  NEW YORK TIMES DIGITAL  Bills & Utilities
# 156       01/02/2020  01/05/2020            SAFEWAY #638          Groceries
#
#      Type  Amount
# 0    Sale    0.99
# 1    Sale   16.00
# 2    Sale   69.00
# 3    Sale   14.95
# 4    Sale   46.28
# ..    ...     ...
# 152  Sale   38.82
# 153  Sale  260.00
# 154  Sale  207.00
# 155  Sale   16.00
# 156  Sale   26.31
#
# [157 rows x 6 columns]

# %%
df['Amount']
# Out:
# 0        0.99
# 1       16.00
# 2       69.00
# 3       14.95
# 4       46.28
#         ...
# 152     38.82
# 153    260.00
# 154    207.00
# 155     16.00
# 156     26.31
# Name: Amount, Length: 157, dtype: float64

# %%
top_food = df[df['Category'] == 'Food & Drink']

# %%
top_food.sort_values('Amount', ascending=False)
# Out:
#     Transaction Date   Post Date                Description      Category  \
# 73        03/19/2020  03/20/2020                  door dash  Food & Drink
# 139       01/25/2020  01/27/2020     THE COUNTER PLEASANTON  Food & Drink
# 34        04/30/2020  05/01/2020                  door dash  Food & Drink
# 128       02/02/2020  02/03/2020                  door dash  Food & Drink
# 6         05/31/2020  05/31/2020              TFK OLO #1015  Food & Drink
# 134       01/29/2020  01/30/2020                  door dash  Food & Drink
# 66        03/26/2020  03/27/2020                  door dash  Food & Drink
# 106       02/20/2020  02/20/2020                  door dash  Food & Drink
# 13        05/24/2020  05/24/2020                  door dash  Food & Drink
# 58        04/03/2020  04/06/2020                     BAAGAN  Food & Drink
# 38        04/24/2020  04/27/2020                     BAAGAN  Food & Drink
# 4         05/31/2020  06/01/2020                  door dash  Food & Drink
# 47   Sale   19.94
# 68   Sale   18.94
# 80   Sale   16.49
# 111  Sale   12.90
# 62   Sale    8.69
# 86   Sale    8.40
# 102  Sale    8.20
# 142  Sale    6.35
# 150  Sale    5.50

# %%
big_spend = top_food.groupby('Description').sum()

# %%
data = big_spend.nlargest(5,'Amount').sort_values(by='Amount', ascending=False)

# %%
data['Amount'] = data['Amount'].astype(int)
x = list(data.index)
y = list(data['Amount'])

# %%
sns.barplot(x=x,y=y)

# %%
purchases = df[df['Type'] == 'Sale']

# %%
len(purchases)
# Out:
# 143

# %%
purchases
# df['Datetime'] = pd.to_datetime(df['date'] + ' ' + df['time'], format=format)
# df = df.set_index(pd.DatetimeIndex(df['Datetime']))
# Out:
#            Transaction Date  Post Date             Description  \
# Post Date
# 2020-06-05       06/04/2020 2020-06-05          APPLE.COM/BILL
# 2020-06-02       06/01/2020 2020-06-02                 NYTIMES
# 2020-06-02       06/01/2020 2020-06-02   AT&amp;T*BILL PAYMENT
# 2020-06-01       06/01/2020 2020-06-01       Audible*MY0H793W1
# 2020-06-01       05/31/2020 2020-06-01               door dash
# ...                     ...        ...                     ...
# 2020-01-13       01/12/2020 2020-01-13     CVS/PHARMACY #09378
# 2020-01-12       01/11/2020 2020-01-12     PATRICK WHALEN  PHD
# 2020-01-05       01/04/2020 2020-01-05           MICROVENTURES
# 2020-01-05       01/03/2020 2020-01-05  NEW YORK TIMES DIGITAL
# 2020-01-05       01/02/2020 2020-01-05            SAFEWAY #638
#
#                      Category  Type  Amount
# Post Date
# 2020-06-05           Shopping  Sale    0.99
# 2020-06-02  Bills & Utilities  Sale   16.00
# 2020-06-02  Bills & Utilities  Sale   69.00
# 2020-06-01  Bills & Utilities  Sale   14.95
# 2020-06-01       Food & Drink  Sale   46.28
# ...                       ...   ...     ...
# 2020-01-13  Health & Wellness  Sale   38.82
# 2020-01-12  Health & Wellness  Sale  260.00
# 2020-01-05           Personal  Sale  207.00
# 2020-01-05  Bills & Utilities  Sale   16.00
# 2020-01-05          Groceries  Sale   26.31
#
# [143 rows x 6 columns]

# %%
purchases.loc[purchases['Description'].str.contains('Audible'), 'Category'] = 'Subscription'

# %%
purchases.loc[purchases['Description'].str.contains('VENTURES'), 'Category'] = 'Investment'

# %%
p_counts = purchases['Category'].value_counts(normalize=True)

# %%
p_counts = p_counts.nlargest(5)

# %%
sns.barplot(x=p_counts.index, y=p_counts.values)
plt.xlabel('Category')
plt.ylabel('Pct of Total')
plt.title('Spending by Category: Jan - Jun')
# Out:
# Text(0.5, 1.0, 'Spending by Category: Jan - Jun')

# %%
places_sum = top_food.groupby(['Description']).sum()
places_count = top_food.groupby(['Description'])['Post Date'].count()

# %%
takeout = np.where(df['Description'] == 'door dash', 'takeout', 'non-takeout')

# %%
by_takeout = df.groupby([takeout])

# %%
by_takeout.size()
# Out:
# non-takeout    137
# takeout         20
# dtype: int64
