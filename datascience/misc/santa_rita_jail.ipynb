# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/Users/toddhendricks/Downloads/Santa Rita Jail COVID-19 Data - Population_Data_Scrape.csv')

# %%
df['cap'] = 3489

# %%
df = df[df['Date'] > '2020-11-25']

# %%
sns.lineplot(x=df['Date'], y=df['SRJ Population'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='SRJ Population'>

# %%
sns.lineplot(x=df['Date'], y=df['Red Patients'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Red Patients'>

# %%
sns.lineplot(x=df['Date'], y=df['Dark Red Patients'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Dark Red Patients'>

# %%
df['percent_positive'] = df['Positive Tests'] / df['Total Tests']

# %%
sns.lineplot(x=df['Date'], y=df['percent_positive'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='percent_positive'>
