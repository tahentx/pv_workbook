# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests

# %%
url = 'https://api.open.fec.gov/v1/candidates/totals/?api_key=HLOQNLXoTUsvR8vb8UpFjQ0Z83oafuN8FMcXNrOh'
response = requests.get(url)
data = response.json()
df = pd.DataFrame(data['results'])

# %%
df
# Out:
#     active_through  address_city address_state  \
# 0             1980     KETCHIKAW            AK
# 1             1990     ANCHORAGE            AK
# 2             1990     FAIRBANKS            AK
# 3             2000        SEWARD            AK
# 4             2002     KETCHIKAN            AK
# 5             2002        JUNEAU            AK
# 6             2004     FAIRBANKS            AK
# 7             2004     FAIRBANKS            AK
# 8             2004     FAIRBANKS            AK
# 9             2000     ANCHORAGE            AK
# 10            2010     ANCHORAGE            AK
# 11            2014  ANCHOR POINT            AK
# 12            2014  ANCHOR POINT            AK
# 13            2014  ANCHOR POINT            AK
# 14            2020       WASILLA            AK
# 15            2020     MANAKOTAK            AK
# 16            1980     ANCHORAGE            AK
# 17            1992        VALDEZ            AK
# 18            1992        VALDEZ            AK
# ...
