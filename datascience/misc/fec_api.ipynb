# %%
import pandas as pd
import requests

# %%
url = 'https://api.open.fec.gov/v1/committee/C00382556/totals/?api_key=HLOQNLXoTUsvR8vb8UpFjQ0Z83oafuN8FMcXNrOh&per_page=100&sort_null_only=True'
response = requests.get(url)
data = response.json()
data
df = pd.DataFrame(data['results'])
nfop = 'C00382556'

# %%
df.shape
# Out:
# (10, 79)

# %%
df.cash_on_hand_beginning_period.plot()
# Out:
# <AxesSubplot:>

# %%
df.contributions.plot()
# Out:
# <AxesSubplot:>

# %%
df.disbursements.plot()
# Out:
# <AxesSubplot:>
