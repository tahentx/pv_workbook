# %%
import pandas as pd
import requests

# %%
url = 'https://api.open.fec.gov/v1/schedules/schedule_a/by_state/totals/?api_key=HLOQNLXoTUsvR8vb8UpFjQ0Z83oafuN8FMcXNrOh&'
response = requests.get(
    url,
    headers={"cycle": '2020'}
)
data = response.json()
data
df = pd.DataFrame(data['results'])

# %%
df
# Out:
#     committee_type                            committee_type_full  count  \
# 0              ALL                                            All     90
# 1   ALL_CANDIDATES                                 All Candidates     52
# 2         ALL_PACS                                       All PACs     25
# 3                H                                          House     23
# 4                Q                                PAC - Qualified     24
# 5                S                                         Senate     29
# 6                W  PAC with Non-Contribution Account - Qualified      1
# 7                Y                              Party - Qualified     13
# 8              ALL                                            All    172
# 9   ALL_CANDIDATES                                 All Candidates     81
# 10        ALL_PACS                                       All PACs     78
# 11               H                                          House     43
# ...
