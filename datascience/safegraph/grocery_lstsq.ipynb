# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_pickle('p1.pkl')

# %%
len(df.columns)
# Out:
# 25

# %%
cali = df[df['region'] == 'CA']

# %%
cali
# Out:
#                           safegraph_place_id  \
# 909872   sg:3a67c5afd8994cad88040c0bb6f33912
# 971363   sg:03ab475c9d054b2a86762df9be395e22
# 481496   sg:ffb3a9ab58ec4f8eae658c46e7535ad7
# 705643   sg:a2de55fab77e46d88e32fcf97aaf62be
# 901537   sg:ba4fec0761054ec4a909a0cccef4f019
# ...                                      ...
# 916595   sg:10adcadf716e48929cf2e9fe390afae3
# 413251   sg:63f3c30686844db28e77881922750bab
# 328950   sg:071ef8fdd6094fff8c6a674091ab429a
# 597809   sg:a6f3505191ea4e1dbc2cca193c588d37
# 1035755  sg:fa522a6e3b8b40a581f0f554337e5bfb
#
#                                  location_name              street_address  \
# 909872                              Me and Z's            1351 E Grand Ave
# 971363                  Arnold Nolan Furniture             3942 W 147th Pl
# 481496                                CrossFit  56805 Twentynine Palms Hwy
# 705643               Regina's Healing HairCuts   860 S San Tomas Aquino Rd
# ...

# %%
tj = df[df['location_name'].str.contains('Trader') ]

# %%
heb = df[df['location_name'].str.contains('H-E-B')]

# %%
albertson = df[df['location_name'].str.contains('Albertson')]

# %%
publix = df[df['location_name'].str.contains('Publix')]

# %%
fl = df[df['location_name'].str.contains('Food Lion')]

# %%
giant = df[df['location_name'].str.contains('Giant')]

# %%
safeway = df[df['location_name'].str.contains('Safeway')]

# %%
store_index = pd.concat([tj,heb,albertson,publix,fl,giant,safeway], ignore_index=True)

# %%
store_index = store_index.drop([9])

# %%
store_index.reset_index()
# Out:
#    index                   safegraph_place_id         location_name  \
# 0      0  sg:212ce4378d184656b7f34e3df93ba060          Trader Joe's
# 1      2  sg:d782480573de4a56ae68dbc1e25392e8          Trader Joe's
# 2      3  sg:997777c848c64b02a65d7bb7f2fed21b          Trader Joe's
# 3      4  sg:1986f0b887c649c19ce758a71cdf7479                 H-E-B
# 4      5  sg:2d3746b2a7644bd2baf61d0f62906403                 H-E-B
# 5      6  sg:8f15e5a410354862a195818157700f46            Albertsons
# 6      7  sg:e7467d7c18db42e9a6551259d2320362  Publix Super Markets
# 7      8  sg:f80636e99cae440f851e68011b9383ad             Food Lion
# 8     10  sg:27ba9d1996d14693b202bf410bdabbbc             Food Lion
# 9     11  sg:3a0e93ce937f46a88974e01a9fe1e704               Safeway
#
#           street_address        city region  postal_code iso_country_code  \
# 0        845 Browning St     Redding     CA        96003               US
# ...

# %%
store_index['avg_house_inc'] = pd.Series([51512,109167,89769,72474,76468,74125,45852,47844,46481,0])
store_index['population'] = pd.Series([45340,7107,63583,70511,39991,40310,62027,13938,53292,26125,0])

# %%
store_index = store_index.head(8)

# %%
np.corrcoef(store_index['population'],store_index.raw_visitor_counts)
# Out:
# array([[ 1.        , -0.31994247],
#        [-0.31994247,  1.        ]])

# %%
a = np.column_stack((store_index['population'],store_index['avg_house_inc']))

# %%
b = store_index.raw_visitor_counts

# %%
x,res = np.linalg.lstsq(a,b)
# Out:
# /Users/toddhendricks/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.

# %%
for i in x:
    print(i)
# Out:
# [-0.00703363  0.00991475]
# [600112.44402986]
# 2
# [231280.48820839  39290.31474915]
