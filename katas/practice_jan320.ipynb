# %%
import random
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
a = [random.randint(50, 200) for iter in range(50)]
b = [random.randint(1, 10) for iter in range(50)]

# %%
sns.violinplot(x=a,y=b)
plt.show()
